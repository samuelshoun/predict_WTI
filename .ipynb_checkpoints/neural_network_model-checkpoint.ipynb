# %%
# standard library imports:

import os


# package imports:

import pandas as pd
import numpy as np
import numpy.random
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse, mean_absolute_error as mae
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
# general settings:

sns.set()

plt.rcParams['figure.figsize'] = (15,8)
plt.rcParams['figure.dpi'] = 300

# %%
# load the csv data prepared & exported by 'data_load_transform_EDA.ipynb'

df = pd.read_csv('predict_WTI.csv', index_col=0)

df
# Out:
#             price  t90d_mean  t30d_mean  f30d_mean  US Production  storage  \
# 1990-01-01  21.84  20.387000  21.151000  22.904667           7565   904134
# 1990-01-02  22.88  20.417111  21.238333  22.933000           7565   904134
# 1990-01-03  23.81  20.460000  21.357333  22.927333           7565   904134
# 1990-01-04  23.41  20.499111  21.463667  22.901667           7565   904134
# 1990-01-05  23.07  20.534444  21.550667  22.889333           7512   904076
# ...           ...        ...        ...        ...            ...      ...
# 2021-10-14  81.43  71.349222  75.840333  82.745000          11400  1043945
# 2021-10-15  82.39  71.467333  76.167000  82.726333          11300  1041820
# 2021-10-16  82.39  71.585444  76.490333  82.675667          11300  1041820
# 2021-10-17  82.39  71.762556  76.833667  82.624333          11300  1041820
# 2021-10-18  82.62  71.932556  77.184667  82.570000          11300  1041820
#
#                      gdp  f30d_mean_gdp  f365d_mean_gdp
# 1990-01-01   9340.478778    9352.766670     9368.661736
# 1990-01-02   9341.326219    9353.614111     9368.475865
# 1990-01-03   9342.173660    9354.461552     9368.287526
# 1990-01-04   9343.021100    9355.303125     9368.096719
# 1990-01-05   9343.868541    9356.138830     9367.903444
# ...                  ...            ...             ...
# 2021-10-14  19617.739033   19653.189860    20048.135191
# 2021-10-15  19620.178531   19655.643559    20050.372550
# 2021-10-16  19622.618029   19658.098442    20052.607767
# 2021-10-17  19625.057527   19660.554507    20054.840844
# 2021-10-18  19627.497025   19663.011756    20057.071779
#
# [11613 rows x 9 columns]

# %%
# reduce the data for modeling a more recent period, and
# split into input (X) and output (y) datasets:

# X = df[-3000:].reset_index().drop(['f30d_mean', 'index'], axis=1)
# y = df[-3000:].reset_index()['f30d_mean']

X = df.reset_index(drop=True).drop('f30d_mean', axis=1)
y = df['f30d_mean'].reset_index(drop=True)

# %%
X
# Out:
#        price  t90d_mean  t30d_mean  US Production  storage           gdp  \
# 0      21.84  20.387000  21.151000           7565   904134   9340.478778
# 1      22.88  20.417111  21.238333           7565   904134   9341.326219
# 2      23.81  20.460000  21.357333           7565   904134   9342.173660
# 3      23.41  20.499111  21.463667           7565   904134   9343.021100
# 4      23.07  20.534444  21.550667           7512   904076   9343.868541
# ...      ...        ...        ...            ...      ...           ...
# 11608  81.43  71.349222  75.840333          11400  1043945  19617.739033
# 11609  82.39  71.467333  76.167000          11300  1041820  19620.178531
# 11610  82.39  71.585444  76.490333          11300  1041820  19622.618029
# 11611  82.39  71.762556  76.833667          11300  1041820  19625.057527
# 11612  82.62  71.932556  77.184667          11300  1041820  19627.497025
#
#        f30d_mean_gdp  f365d_mean_gdp
# 0        9352.766670     9368.661736
# 1        9353.614111     9368.475865
# 2        9354.461552     9368.287526
# 3        9355.303125     9368.096719
# 4        9356.138830     9367.903444
# ...              ...             ...
# 11608   19653.189860    20048.135191
# 11609   19655.643559    20050.372550
# 11610   19658.098442    20052.607767
# 11611   19660.554507    20054.840844
# 11612   19663.011756    20057.071779
#
# [11613 rows x 8 columns]

# %%
y
# Out:
# 0        22.904667
# 1        22.933000
# 2        22.927333
# 3        22.901667
# 4        22.889333
#            ...
# 11608    82.745000
# 11609    82.726333
# 11610    82.675667
# 11611    82.624333
# 11612    82.570000
# Name: f30d_mean, Length: 11613, dtype: float64

# %%
# create the train-test split:

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scal = RobustScaler()

X_train = scal.fit_transform(X_train)
X_test = scal.transform(X_test)

# %%
# examine X and y shapes:

print('X shape: ' + str(X.shape))
print('y shape: ' + str(y.shape))
print('X_train shape: ' + str(X_train.shape))
print('y_train shape: ' + str(y_train.shape))
# Out:
# X shape: (11613, 8)
# y shape: (11613,)
# X_train shape: (8129, 8)
# y_train shape: (8129,)

# %%
# build the neural network:

mod = Sequential()

mod.add(Dense(128, activation='relu'))
mod.add(Dense(128, activation='relu'))
mod.add(Dense(128, activation='relu'))
mod.add(Dense(1))

mod.compile(optimizer='adam', loss='mse')


# set up early stopping:
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# set up checkpoints to recall the best model:
model_cp = tf.keras.callbacks.ModelCheckpoint('models_best_nn.h5', monitor='val_loss', verbose=1, save_best_only=True)

# %%
# train the NN:

mod.fit(X_train, y_train, epochs=1000, validation_data=(X_test, y_test), callbacks=[early_stop, model_cp], verbose=0)
# Out:
# Epoch 00001: val_loss improved from inf to 25.00420, saving model to models_best_nn.h5
#
# Epoch 00002: val_loss improved from 25.00420 to 12.18013, saving model to models_best_nn.h5
#
# Epoch 00003: val_loss improved from 12.18013 to 9.65186, saving model to models_best_nn.h5
#
# Epoch 00004: val_loss did not improve from 9.65186
#
# Epoch 00005: val_loss did not improve from 9.65186
#
# Epoch 00006: val_loss improved from 9.65186 to 8.55854, saving model to models_best_nn.h5
#
# Epoch 00007: val_loss improved from 8.55854 to 8.13710, saving model to models_best_nn.h5
#
# Epoch 00008: val_loss improved from 8.13710 to 7.68279, saving model to models_best_nn.h5
#
# Epoch 00009: val_loss did not improve from 7.68279
#
# Epoch 00010: val_loss did not improve from 7.68279
#
# Epoch 00011: val_loss did not improve from 7.68279
#
# Epoch 00012: val_loss improved from 7.68279 to 7.67767, saving model to models_best_nn.h5
#
# Epoch 00013: val_loss did not improve from 7.67767
#
# Epoch 00014: val_loss improved from 7.67767 to 7.43594, saving model to models_best_nn.h5
#
# Epoch 00015: val_loss improved from 7.43594 to 7.23150, saving model to models_best_nn.h5
#
# Epoch 00016: val_loss did not improve from 7.23150
#
# Epoch 00017: val_loss did not improve from 7.23150
#
# Epoch 00018: val_loss did not improve from 7.23150
#
# Epoch 00019: val_loss did not improve from 7.23150
#
# Epoch 00020: val_loss did not improve from 7.23150
#
# Epoch 00021: val_loss did not improve from 7.23150
#
# Epoch 00022: val_loss did not improve from 7.23150
#
# Epoch 00023: val_loss improved from 7.23150 to 6.42671, saving model to models_best_nn.h5
#
# Epoch 00024: val_loss did not improve from 6.42671
#
# Epoch 00025: val_loss did not improve from 6.42671
#
# Epoch 00026: val_loss did not improve from 6.42671
#
# Epoch 00027: val_loss did not improve from 6.42671
#
# Epoch 00028: val_loss did not improve from 6.42671
#
# Epoch 00029: val_loss did not improve from 6.42671
#
# Epoch 00030: val_loss did not improve from 6.42671
#
# Epoch 00031: val_loss improved from 6.42671 to 6.02316, saving model to models_best_nn.h5
#
# Epoch 00032: val_loss did not improve from 6.02316
#
# Epoch 00033: val_loss did not improve from 6.02316
#
# Epoch 00034: val_loss did not improve from 6.02316
#
# Epoch 00035: val_loss did not improve from 6.02316
#
# Epoch 00036: val_loss did not improve from 6.02316
#
# Epoch 00037: val_loss did not improve from 6.02316
#
# Epoch 00038: val_loss did not improve from 6.02316
#
# Epoch 00039: val_loss did not improve from 6.02316
#
# Epoch 00040: val_loss did not improve from 6.02316
#
# Epoch 00041: val_loss improved from 6.02316 to 5.95477, saving model to models_best_nn.h5
#
# Epoch 00042: val_loss did not improve from 5.95477
#
# Epoch 00043: val_loss did not improve from 5.95477
#
# Epoch 00044: val_loss did not improve from 5.95477
#
# Epoch 00045: val_loss did not improve from 5.95477
#
# Epoch 00046: val_loss did not improve from 5.95477
#
# Epoch 00047: val_loss did not improve from 5.95477
#
# Epoch 00048: val_loss did not improve from 5.95477
#
# Epoch 00049: val_loss improved from 5.95477 to 5.49799, saving model to models_best_nn.h5
#
# Epoch 00050: val_loss did not improve from 5.49799
#
# Epoch 00051: val_loss did not improve from 5.49799
#
# Epoch 00052: val_loss did not improve from 5.49799
#
# Epoch 00053: val_loss did not improve from 5.49799
#
# Epoch 00054: val_loss did not improve from 5.49799
#
# Epoch 00055: val_loss did not improve from 5.49799
#
# Epoch 00056: val_loss did not improve from 5.49799
#
# Epoch 00057: val_loss did not improve from 5.49799
#
# Epoch 00058: val_loss did not improve from 5.49799
#
# Epoch 00059: val_loss improved from 5.49799 to 5.40120, saving model to models_best_nn.h5
#
# Epoch 00060: val_loss did not improve from 5.40120
#
# Epoch 00061: val_loss did not improve from 5.40120
#
# Epoch 00062: val_loss improved from 5.40120 to 5.31907, saving model to models_best_nn.h5
#
# Epoch 00063: val_loss did not improve from 5.31907
#
# Epoch 00064: val_loss did not improve from 5.31907
#
# Epoch 00065: val_loss did not improve from 5.31907
#
# Epoch 00066: val_loss did not improve from 5.31907
#
# Epoch 00067: val_loss did not improve from 5.31907
#
# Epoch 00068: val_loss did not improve from 5.31907
#
# Epoch 00069: val_loss did not improve from 5.31907
#
# Epoch 00070: val_loss did not improve from 5.31907
#
# Epoch 00071: val_loss improved from 5.31907 to 5.29407, saving model to models_best_nn.h5
#
# Epoch 00072: val_loss improved from 5.29407 to 5.17653, saving model to models_best_nn.h5
#
# Epoch 00073: val_loss improved from 5.17653 to 4.90257, saving model to models_best_nn.h5
#
# Epoch 00074: val_loss did not improve from 4.90257
#
# Epoch 00075: val_loss did not improve from 4.90257
#
# Epoch 00076: val_loss did not improve from 4.90257
#
# Epoch 00077: val_loss did not improve from 4.90257
#
# Epoch 00078: val_loss did not improve from 4.90257
#
# Epoch 00079: val_loss did not improve from 4.90257
#
# Epoch 00080: val_loss did not improve from 4.90257
#
# Epoch 00081: val_loss improved from 4.90257 to 4.73060, saving model to models_best_nn.h5
#
# Epoch 00082: val_loss did not improve from 4.73060
#
# Epoch 00083: val_loss did not improve from 4.73060
#
# Epoch 00084: val_loss did not improve from 4.73060
#
# Epoch 00085: val_loss improved from 4.73060 to 4.47539, saving model to models_best_nn.h5
#
# Epoch 00086: val_loss did not improve from 4.47539
#
# Epoch 00087: val_loss did not improve from 4.47539
#
# Epoch 00088: val_loss did not improve from 4.47539
#
# Epoch 00089: val_loss did not improve from 4.47539
#
# Epoch 00090: val_loss did not improve from 4.47539
#
# Epoch 00091: val_loss did not improve from 4.47539
#
# Epoch 00092: val_loss did not improve from 4.47539
#
# Epoch 00093: val_loss did not improve from 4.47539
#
# Epoch 00094: val_loss did not improve from 4.47539
#
# Epoch 00095: val_loss did not improve from 4.47539
#
# Epoch 00096: val_loss did not improve from 4.47539
#
# Epoch 00097: val_loss did not improve from 4.47539
#
# Epoch 00098: val_loss did not improve from 4.47539
#
# Epoch 00099: val_loss did not improve from 4.47539
#
# Epoch 00100: val_loss did not improve from 4.47539
#
# Epoch 00101: val_loss did not improve from 4.47539
#
# Epoch 00102: val_loss improved from 4.47539 to 4.29925, saving model to models_best_nn.h5
#
# Epoch 00103: val_loss did not improve from 4.29925
#
# Epoch 00104: val_loss did not improve from 4.29925
#
# Epoch 00105: val_loss did not improve from 4.29925
#
# Epoch 00106: val_loss improved from 4.29925 to 4.02517, saving model to models_best_nn.h5
#
# Epoch 00107: val_loss did not improve from 4.02517
#
# Epoch 00108: val_loss did not improve from 4.02517
#
# Epoch 00109: val_loss did not improve from 4.02517
#
# Epoch 00110: val_loss did not improve from 4.02517
#
# Epoch 00111: val_loss did not improve from 4.02517
#
# Epoch 00112: val_loss did not improve from 4.02517
#
# Epoch 00113: val_loss did not improve from 4.02517
#
# Epoch 00114: val_loss did not improve from 4.02517
#
# Epoch 00115: val_loss did not improve from 4.02517
#
# Epoch 00116: val_loss did not improve from 4.02517
#
# Epoch 00117: val_loss did not improve from 4.02517
#
# Epoch 00118: val_loss did not improve from 4.02517
#
# Epoch 00119: val_loss did not improve from 4.02517
#
# Epoch 00120: val_loss did not improve from 4.02517
#
# Epoch 00121: val_loss did not improve from 4.02517
#
# Epoch 00122: val_loss did not improve from 4.02517
#
# Epoch 00123: val_loss improved from 4.02517 to 3.79020, saving model to models_best_nn.h5
#
# Epoch 00124: val_loss did not improve from 3.79020
#
# Epoch 00125: val_loss did not improve from 3.79020
#
# Epoch 00126: val_loss did not improve from 3.79020
#
# Epoch 00127: val_loss did not improve from 3.79020
#
# Epoch 00128: val_loss did not improve from 3.79020
#
# Epoch 00129: val_loss did not improve from 3.79020
#
# Epoch 00130: val_loss did not improve from 3.79020
#
# Epoch 00131: val_loss did not improve from 3.79020
#
# Epoch 00132: val_loss did not improve from 3.79020
#
# Epoch 00133: val_loss did not improve from 3.79020
#
# Epoch 00134: val_loss improved from 3.79020 to 3.40829, saving model to models_best_nn.h5
#
# Epoch 00135: val_loss did not improve from 3.40829
#
# Epoch 00136: val_loss did not improve from 3.40829
#
# Epoch 00137: val_loss did not improve from 3.40829
#
# Epoch 00138: val_loss improved from 3.40829 to 3.32861, saving model to models_best_nn.h5
#
# Epoch 00139: val_loss did not improve from 3.32861
# Epoch 00140: val_loss did not improve from 3.32861
#
# Epoch 00141: val_loss improved from 3.32861 to 3.29498, saving model to models_best_nn.h5
#
# Epoch 00142: val_loss did not improve from 3.29498
#
# Epoch 00143: val_loss did not improve from 3.29498
#
# Epoch 00144: val_loss did not improve from 3.29498
#
# Epoch 00145: val_loss did not improve from 3.29498
#
# Epoch 00146: val_loss did not improve from 3.29498
#
# Epoch 00147: val_loss did not improve from 3.29498
#
# Epoch 00148: val_loss did not improve from 3.29498
#
# Epoch 00149: val_loss did not improve from 3.29498
#
# Epoch 00150: val_loss did not improve from 3.29498
#
# Epoch 00151: val_loss did not improve from 3.29498
#
# Epoch 00152: val_loss improved from 3.29498 to 3.09090, saving model to models_best_nn.h5
#
# Epoch 00153: val_loss improved from 3.09090 to 3.07280, saving model to models_best_nn.h5
#
# Epoch 00154: val_loss did not improve from 3.07280
#
# Epoch 00155: val_loss did not improve from 3.07280
#
# Epoch 00156: val_loss did not improve from 3.07280
#
# Epoch 00157: val_loss did not improve from 3.07280
#
# Epoch 00158: val_loss did not improve from 3.07280
#
# Epoch 00159: val_loss did not improve from 3.07280
#
# Epoch 00160: val_loss did not improve from 3.07280
#
# Epoch 00161: val_loss did not improve from 3.07280
#
# Epoch 00162: val_loss did not improve from 3.07280
#
# Epoch 00163: val_loss did not improve from 3.07280
#
# Epoch 00164: val_loss did not improve from 3.07280
#
# Epoch 00165: val_loss did not improve from 3.07280
#
# Epoch 00166: val_loss did not improve from 3.07280
#
# Epoch 00167: val_loss improved from 3.07280 to 2.91397, saving model to models_best_nn.h5
#
# Epoch 00168: val_loss improved from 2.91397 to 2.80640, saving model to models_best_nn.h5
#
# Epoch 00169: val_loss did not improve from 2.80640
#
# Epoch 00170: val_loss did not improve from 2.80640
#
# Epoch 00171: val_loss did not improve from 2.80640
#
# Epoch 00172: val_loss did not improve from 2.80640
#
# Epoch 00173: val_loss did not improve from 2.80640
#
# Epoch 00174: val_loss did not improve from 2.80640
#
# Epoch 00175: val_loss did not improve from 2.80640
#
# Epoch 00176: val_loss did not improve from 2.80640
#
# Epoch 00177: val_loss improved from 2.80640 to 2.71175, saving model to models_best_nn.h5
#
# Epoch 00178: val_loss did not improve from 2.71175
#
# Epoch 00179: val_loss did not improve from 2.71175
#
# Epoch 00180: val_loss did not improve from 2.71175
#
# Epoch 00181: val_loss did not improve from 2.71175
#
# Epoch 00182: val_loss did not improve from 2.71175
#
# Epoch 00183: val_loss did not improve from 2.71175
#
# Epoch 00184: val_loss did not improve from 2.71175
#
# Epoch 00185: val_loss did not improve from 2.71175
#
# Epoch 00186: val_loss did not improve from 2.71175
#
# Epoch 00187: val_loss did not improve from 2.71175
#
# Epoch 00188: val_loss improved from 2.71175 to 2.61390, saving model to models_best_nn.h5
#
# Epoch 00189: val_loss did not improve from 2.61390
#
# Epoch 00190: val_loss improved from 2.61390 to 2.57686, saving model to models_best_nn.h5
#
# Epoch 00191: val_loss did not improve from 2.57686
#
# Epoch 00192: val_loss did not improve from 2.57686
#
# Epoch 00193: val_loss did not improve from 2.57686
#
# Epoch 00194: val_loss did not improve from 2.57686
#
# Epoch 00195: val_loss did not improve from 2.57686
#
# Epoch 00196: val_loss did not improve from 2.57686
#
# Epoch 00197: val_loss did not improve from 2.57686
#
# Epoch 00198: val_loss did not improve from 2.57686
#
# Epoch 00199: val_loss improved from 2.57686 to 2.44779, saving model to models_best_nn.h5
#
# Epoch 00200: val_loss did not improve from 2.44779
#
# Epoch 00201: val_loss improved from 2.44779 to 2.44584, saving model to models_best_nn.h5
#
# Epoch 00202: val_loss did not improve from 2.44584
#
# Epoch 00203: val_loss did not improve from 2.44584
#
# Epoch 00204: val_loss did not improve from 2.44584
#
# Epoch 00205: val_loss improved from 2.44584 to 2.42186, saving model to models_best_nn.h5
#
# Epoch 00206: val_loss did not improve from 2.42186
#
# Epoch 00207: val_loss improved from 2.42186 to 2.32392, saving model to models_best_nn.h5
#
# Epoch 00208: val_loss did not improve from 2.32392
#
# Epoch 00209: val_loss did not improve from 2.32392
#
# Epoch 00210: val_loss did not improve from 2.32392
#
# Epoch 00211: val_loss did not improve from 2.32392
#
# Epoch 00212: val_loss did not improve from 2.32392
#
# Epoch 00213: val_loss did not improve from 2.32392
#
# Epoch 00214: val_loss did not improve from 2.32392
#
# Epoch 00215: val_loss did not improve from 2.32392
#
# Epoch 00216: val_loss did not improve from 2.32392
#
# Epoch 00217: val_loss did not improve from 2.32392
#
# Epoch 00218: val_loss did not improve from 2.32392
#
# Epoch 00219: val_loss did not improve from 2.32392
#
# Epoch 00220: val_loss did not improve from 2.32392
#
# Epoch 00221: val_loss improved from 2.32392 to 2.09885, saving model to models_best_nn.h5
#
# Epoch 00222: val_loss did not improve from 2.09885
#
# Epoch 00223: val_loss did not improve from 2.09885
#
# Epoch 00224: val_loss did not improve from 2.09885
#
# Epoch 00225: val_loss did not improve from 2.09885
#
# Epoch 00226: val_loss did not improve from 2.09885
#
# Epoch 00227: val_loss did not improve from 2.09885
#
# Epoch 00228: val_loss did not improve from 2.09885
#
# Epoch 00229: val_loss did not improve from 2.09885
#
# Epoch 00230: val_loss improved from 2.09885 to 1.96205, saving model to models_best_nn.h5
#
# Epoch 00231: val_loss did not improve from 1.96205
#
# Epoch 00232: val_loss did not improve from 1.96205
#
# Epoch 00233: val_loss did not improve from 1.96205
#
# Epoch 00234: val_loss did not improve from 1.96205
#
# Epoch 00235: val_loss did not improve from 1.96205
#
# Epoch 00236: val_loss did not improve from 1.96205
#
# Epoch 00237: val_loss improved from 1.96205 to 1.90598, saving model to models_best_nn.h5
#
# Epoch 00238: val_loss did not improve from 1.90598
#
# Epoch 00239: val_loss did not improve from 1.90598
#
# Epoch 00240: val_loss did not improve from 1.90598
#
# Epoch 00241: val_loss did not improve from 1.90598
#
# Epoch 00242: val_loss did not improve from 1.90598
#
# Epoch 00243: val_loss did not improve from 1.90598
#
# Epoch 00244: val_loss did not improve from 1.90598
#
# Epoch 00245: val_loss did not improve from 1.90598
#
# Epoch 00246: val_loss did not improve from 1.90598
#
# Epoch 00247: val_loss did not improve from 1.90598
#
# Epoch 00248: val_loss did not improve from 1.90598
#
# Epoch 00249: val_loss did not improve from 1.90598
#
# Epoch 00250: val_loss improved from 1.90598 to 1.87330, saving model to models_best_nn.h5
#
# Epoch 00251: val_loss did not improve from 1.87330
#
# Epoch 00252: val_loss did not improve from 1.87330
#
# Epoch 00253: val_loss did not improve from 1.87330
#
# Epoch 00254: val_loss did not improve from 1.87330
#
# Epoch 00255: val_loss did not improve from 1.87330
#
# Epoch 00256: val_loss did not improve from 1.87330
#
# Epoch 00257: val_loss did not improve from 1.87330
#
# Epoch 00258: val_loss did not improve from 1.87330
#
# Epoch 00259: val_loss did not improve from 1.87330
#
# Epoch 00260: val_loss did not improve from 1.87330
#
# Epoch 00261: val_loss did not improve from 1.87330
#
# Epoch 00262: val_loss did not improve from 1.87330
#
# Epoch 00263: val_loss improved from 1.87330 to 1.80165, saving model to models_best_nn.h5
#
# Epoch 00264: val_loss did not improve from 1.80165
#
# Epoch 00265: val_loss did not improve from 1.80165
#
# Epoch 00266: val_loss improved from 1.80165 to 1.57483, saving model to models_best_nn.h5
#
# Epoch 00267: val_loss did not improve from 1.57483
#
# Epoch 00268: val_loss did not improve from 1.57483
#
# Epoch 00269: val_loss did not improve from 1.57483
#
# Epoch 00270: val_loss did not improve from 1.57483
#
# Epoch 00271: val_loss did not improve from 1.57483
#
# Epoch 00272: val_loss did not improve from 1.57483
#
# Epoch 00273: val_loss did not improve from 1.57483
#
# Epoch 00274: val_loss did not improve from 1.57483
#
# Epoch 00275: val_loss did not improve from 1.57483
#
# Epoch 00276: val_loss did not improve from 1.57483
#
# Epoch 00277: val_loss did not improve from 1.57483
#
# Epoch 00278: val_loss did not improve from 1.57483
#
# Epoch 00279: val_loss did not improve from 1.57483
#
# Epoch 00280: val_loss did not improve from 1.57483
#
# Epoch 00281: val_loss did not improve from 1.57483
#
# Epoch 00282: val_loss did not improve from 1.57483
#
# Epoch 00283: val_loss improved from 1.57483 to 1.56465, saving model to models_best_nn.h5
# Epoch 00284: val_loss did not improve from 1.56465
#
# Epoch 00285: val_loss did not improve from 1.56465
#
# Epoch 00286: val_loss did not improve from 1.56465
#
# Epoch 00287: val_loss improved from 1.56465 to 1.43538, saving model to models_best_nn.h5
#
# Epoch 00288: val_loss did not improve from 1.43538
#
# Epoch 00289: val_loss did not improve from 1.43538
#
# Epoch 00290: val_loss did not improve from 1.43538
#
# Epoch 00291: val_loss improved from 1.43538 to 1.43078, saving model to models_best_nn.h5
#
# Epoch 00292: val_loss did not improve from 1.43078
#
# Epoch 00293: val_loss did not improve from 1.43078
#
# Epoch 00294: val_loss did not improve from 1.43078
#
# Epoch 00295: val_loss did not improve from 1.43078
#
# Epoch 00296: val_loss did not improve from 1.43078
#
# Epoch 00297: val_loss did not improve from 1.43078
#
# Epoch 00298: val_loss did not improve from 1.43078
#
# Epoch 00299: val_loss improved from 1.43078 to 1.32497, saving model to models_best_nn.h5
#
# Epoch 00300: val_loss did not improve from 1.32497
#
# Epoch 00301: val_loss did not improve from 1.32497
#
# Epoch 00302: val_loss did not improve from 1.32497
#
# Epoch 00303: val_loss did not improve from 1.32497
#
# Epoch 00304: val_loss did not improve from 1.32497
#
# Epoch 00305: val_loss did not improve from 1.32497
#
# Epoch 00306: val_loss did not improve from 1.32497
#
# Epoch 00307: val_loss did not improve from 1.32497
#
# Epoch 00308: val_loss did not improve from 1.32497
#
# Epoch 00309: val_loss did not improve from 1.32497
#
# Epoch 00310: val_loss did not improve from 1.32497
#
# Epoch 00311: val_loss did not improve from 1.32497
#
# Epoch 00312: val_loss did not improve from 1.32497
#
# Epoch 00313: val_loss did not improve from 1.32497
#
# Epoch 00314: val_loss did not improve from 1.32497
#
# Epoch 00315: val_loss did not improve from 1.32497
#
# Epoch 00316: val_loss did not improve from 1.32497
#
# Epoch 00317: val_loss did not improve from 1.32497
#
# Epoch 00318: val_loss did not improve from 1.32497
#
# Epoch 00319: val_loss improved from 1.32497 to 1.16924, saving model to models_best_nn.h5
#
# Epoch 00320: val_loss did not improve from 1.16924
#
# Epoch 00321: val_loss did not improve from 1.16924
#
# Epoch 00322: val_loss did not improve from 1.16924
#
# Epoch 00323: val_loss did not improve from 1.16924
#
# Epoch 00324: val_loss did not improve from 1.16924
#
# Epoch 00325: val_loss did not improve from 1.16924
#
# Epoch 00326: val_loss did not improve from 1.16924
#
# Epoch 00327: val_loss did not improve from 1.16924
#
# Epoch 00328: val_loss did not improve from 1.16924
#
# Epoch 00329: val_loss did not improve from 1.16924
#
# Epoch 00330: val_loss did not improve from 1.16924
#
# Epoch 00331: val_loss did not improve from 1.16924
#
# Epoch 00332: val_loss did not improve from 1.16924
#
# Epoch 00333: val_loss did not improve from 1.16924
#
# Epoch 00334: val_loss did not improve from 1.16924
#
# Epoch 00335: val_loss did not improve from 1.16924
#
# Epoch 00336: val_loss did not improve from 1.16924
#
# Epoch 00337: val_loss did not improve from 1.16924
#
# Epoch 00338: val_loss did not improve from 1.16924
#
# Epoch 00339: val_loss did not improve from 1.16924
#
# Epoch 00340: val_loss did not improve from 1.16924
#
# Epoch 00341: val_loss did not improve from 1.16924
#
# Epoch 00342: val_loss did not improve from 1.16924
#
# Epoch 00343: val_loss did not improve from 1.16924
#
# Epoch 00344: val_loss did not improve from 1.16924
#
# Epoch 00345: val_loss did not improve from 1.16924
#
# Epoch 00346: val_loss did not improve from 1.16924
#
# Epoch 00347: val_loss did not improve from 1.16924
#
# Epoch 00348: val_loss did not improve from 1.16924
#
# Epoch 00349: val_loss improved from 1.16924 to 1.05401, saving model to models_best_nn.h5
#
# Epoch 00350: val_loss did not improve from 1.05401
#
# Epoch 00351: val_loss did not improve from 1.05401
#
# Epoch 00352: val_loss did not improve from 1.05401
#
# Epoch 00353: val_loss did not improve from 1.05401
#
# Epoch 00354: val_loss did not improve from 1.05401
#
# Epoch 00355: val_loss did not improve from 1.05401
#
# Epoch 00356: val_loss did not improve from 1.05401
#
# Epoch 00357: val_loss did not improve from 1.05401
#
# Epoch 00358: val_loss did not improve from 1.05401
#
# Epoch 00359: val_loss did not improve from 1.05401
#
# Epoch 00360: val_loss did not improve from 1.05401
#
# Epoch 00361: val_loss did not improve from 1.05401
#
# Epoch 00362: val_loss did not improve from 1.05401
#
# Epoch 00363: val_loss did not improve from 1.05401
#
# Epoch 00364: val_loss did not improve from 1.05401
#
# Epoch 00365: val_loss did not improve from 1.05401
#
# Epoch 00366: val_loss did not improve from 1.05401
#
# Epoch 00367: val_loss did not improve from 1.05401
#
# Epoch 00368: val_loss did not improve from 1.05401
#
# Epoch 00369: val_loss did not improve from 1.05401
#
# Epoch 00370: val_loss did not improve from 1.05401
#
# Epoch 00371: val_loss did not improve from 1.05401
#
# Epoch 00372: val_loss did not improve from 1.05401
#
# Epoch 00373: val_loss did not improve from 1.05401
#
# Epoch 00374: val_loss did not improve from 1.05401
#
# Epoch 00375: val_loss did not improve from 1.05401
#
# Epoch 00376: val_loss did not improve from 1.05401
#
# Epoch 00377: val_loss did not improve from 1.05401
#
# Epoch 00378: val_loss did not improve from 1.05401
#
# Epoch 00379: val_loss did not improve from 1.05401
#
# Epoch 00380: val_loss did not improve from 1.05401
#
# Epoch 00381: val_loss improved from 1.05401 to 1.05087, saving model to models_best_nn.h5
#
# Epoch 00382: val_loss did not improve from 1.05087
#
# Epoch 00383: val_loss did not improve from 1.05087
#
# Epoch 00384: val_loss did not improve from 1.05087
#
# Epoch 00385: val_loss did not improve from 1.05087
#
# Epoch 00386: val_loss did not improve from 1.05087
#
# Epoch 00387: val_loss did not improve from 1.05087
#
# Epoch 00388: val_loss did not improve from 1.05087
#
# Epoch 00389: val_loss did not improve from 1.05087
#
# Epoch 00390: val_loss did not improve from 1.05087
#
# Epoch 00391: val_loss did not improve from 1.05087
#
# Epoch 00392: val_loss did not improve from 1.05087
#
# Epoch 00393: val_loss did not improve from 1.05087
#
# Epoch 00394: val_loss did not improve from 1.05087
#
# Epoch 00395: val_loss did not improve from 1.05087
#
# Epoch 00396: val_loss did not improve from 1.05087
#
# Epoch 00397: val_loss did not improve from 1.05087
#
# Epoch 00398: val_loss did not improve from 1.05087
#
# Epoch 00399: val_loss improved from 1.05087 to 0.99557, saving model to models_best_nn.h5
#
# Epoch 00400: val_loss did not improve from 0.99557
#
# Epoch 00401: val_loss did not improve from 0.99557
#
# Epoch 00402: val_loss did not improve from 0.99557
#
# Epoch 00403: val_loss did not improve from 0.99557
#
# Epoch 00404: val_loss did not improve from 0.99557
#
# Epoch 00405: val_loss did not improve from 0.99557
#
# Epoch 00406: val_loss did not improve from 0.99557
#
# Epoch 00407: val_loss did not improve from 0.99557
#
# Epoch 00408: val_loss did not improve from 0.99557
#
# Epoch 00409: val_loss did not improve from 0.99557
#
# Epoch 00410: val_loss improved from 0.99557 to 0.98368, saving model to models_best_nn.h5
#
# Epoch 00411: val_loss did not improve from 0.98368
#
# Epoch 00412: val_loss did not improve from 0.98368
#
# Epoch 00413: val_loss did not improve from 0.98368
#
# Epoch 00414: val_loss did not improve from 0.98368
#
# Epoch 00415: val_loss did not improve from 0.98368
#
# Epoch 00416: val_loss did not improve from 0.98368
#
# Epoch 00417: val_loss did not improve from 0.98368
#
# Epoch 00418: val_loss did not improve from 0.98368
#
# Epoch 00419: val_loss did not improve from 0.98368
#
# Epoch 00420: val_loss did not improve from 0.98368
#
# Epoch 00421: val_loss did not improve from 0.98368
#
# Epoch 00422: val_loss did not improve from 0.98368
#
# Epoch 00423: val_loss did not improve from 0.98368
#
# Epoch 00424: val_loss did not improve from 0.98368
#
# Epoch 00425: val_loss did not improve from 0.98368
#
# Epoch 00426: val_loss did not improve from 0.98368
#
# Epoch 00427: val_loss did not improve from 0.98368
#
# Epoch 00428: val_loss did not improve from 0.98368
#
# Epoch 00429: val_loss did not improve from 0.98368
#
# Epoch 00430: val_loss improved from 0.98368 to 0.98176, saving model to models_best_nn.h5
#
# Epoch 00431: val_loss did not improve from 0.98176
#
# Epoch 00432: val_loss did not improve from 0.98176
#
# Epoch 00433: val_loss did not improve from 0.98176
#
# Epoch 00434: val_loss did not improve from 0.98176
# Epoch 00435: val_loss did not improve from 0.98176
#
# Epoch 00436: val_loss did not improve from 0.98176
#
# Epoch 00437: val_loss did not improve from 0.98176
#
# Epoch 00438: val_loss did not improve from 0.98176
#
# Epoch 00439: val_loss did not improve from 0.98176
#
# Epoch 00440: val_loss did not improve from 0.98176
#
# Epoch 00441: val_loss did not improve from 0.98176
#
# Epoch 00442: val_loss improved from 0.98176 to 0.90715, saving model to models_best_nn.h5
#
# Epoch 00443: val_loss did not improve from 0.90715
#
# Epoch 00444: val_loss did not improve from 0.90715
#
# Epoch 00445: val_loss did not improve from 0.90715
#
# Epoch 00446: val_loss did not improve from 0.90715
#
# Epoch 00447: val_loss did not improve from 0.90715
#
# Epoch 00448: val_loss did not improve from 0.90715
#
# Epoch 00449: val_loss did not improve from 0.90715
#
# Epoch 00450: val_loss did not improve from 0.90715
#
# Epoch 00451: val_loss did not improve from 0.90715
#
# Epoch 00452: val_loss did not improve from 0.90715
#
# Epoch 00453: val_loss improved from 0.90715 to 0.90151, saving model to models_best_nn.h5
#
# Epoch 00454: val_loss did not improve from 0.90151
#
# Epoch 00455: val_loss did not improve from 0.90151
#
# Epoch 00456: val_loss did not improve from 0.90151
#
# Epoch 00457: val_loss did not improve from 0.90151
#
# Epoch 00458: val_loss did not improve from 0.90151
#
# Epoch 00459: val_loss did not improve from 0.90151
#
# Epoch 00460: val_loss did not improve from 0.90151
#
# Epoch 00461: val_loss did not improve from 0.90151
#
# Epoch 00462: val_loss did not improve from 0.90151
#
# Epoch 00463: val_loss did not improve from 0.90151
#
# Epoch 00464: val_loss did not improve from 0.90151
#
# Epoch 00465: val_loss did not improve from 0.90151
#
# Epoch 00466: val_loss did not improve from 0.90151
#
# Epoch 00467: val_loss did not improve from 0.90151
#
# Epoch 00468: val_loss did not improve from 0.90151
#
# Epoch 00469: val_loss did not improve from 0.90151
#
# Epoch 00470: val_loss did not improve from 0.90151
#
# Epoch 00471: val_loss did not improve from 0.90151
#
# Epoch 00472: val_loss did not improve from 0.90151
#
# Epoch 00473: val_loss did not improve from 0.90151
#
# Epoch 00474: val_loss did not improve from 0.90151
#
# Epoch 00475: val_loss did not improve from 0.90151
#
# Epoch 00476: val_loss did not improve from 0.90151
#
# Epoch 00477: val_loss did not improve from 0.90151
#
# Epoch 00478: val_loss did not improve from 0.90151
#
# Epoch 00479: val_loss improved from 0.90151 to 0.85581, saving model to models_best_nn.h5
#
# Epoch 00480: val_loss did not improve from 0.85581
#
# Epoch 00481: val_loss improved from 0.85581 to 0.83881, saving model to models_best_nn.h5
#
# Epoch 00482: val_loss did not improve from 0.83881
#
# Epoch 00483: val_loss did not improve from 0.83881
#
# Epoch 00484: val_loss did not improve from 0.83881
#
# Epoch 00485: val_loss did not improve from 0.83881
#
# Epoch 00486: val_loss did not improve from 0.83881
#
# Epoch 00487: val_loss did not improve from 0.83881
#
# Epoch 00488: val_loss did not improve from 0.83881
#
# Epoch 00489: val_loss did not improve from 0.83881
#
# Epoch 00490: val_loss did not improve from 0.83881
#
# Epoch 00491: val_loss did not improve from 0.83881
#
# Epoch 00492: val_loss did not improve from 0.83881
#
# Epoch 00493: val_loss did not improve from 0.83881
#
# Epoch 00494: val_loss did not improve from 0.83881
#
# Epoch 00495: val_loss did not improve from 0.83881
#
# Epoch 00496: val_loss did not improve from 0.83881
#
# Epoch 00497: val_loss did not improve from 0.83881
#
# Epoch 00498: val_loss did not improve from 0.83881
#
# Epoch 00499: val_loss did not improve from 0.83881
#
# Epoch 00500: val_loss did not improve from 0.83881
#
# Epoch 00501: val_loss did not improve from 0.83881
#
# Epoch 00502: val_loss did not improve from 0.83881
#
# Epoch 00503: val_loss did not improve from 0.83881
#
# Epoch 00504: val_loss did not improve from 0.83881
#
# Epoch 00505: val_loss did not improve from 0.83881
#
# Epoch 00506: val_loss did not improve from 0.83881
#
# Epoch 00507: val_loss did not improve from 0.83881
#
# Epoch 00508: val_loss did not improve from 0.83881
#
# Epoch 00509: val_loss did not improve from 0.83881
#
# Epoch 00510: val_loss did not improve from 0.83881
#
# Epoch 00511: val_loss did not improve from 0.83881
#
# Epoch 00512: val_loss did not improve from 0.83881
#
# Epoch 00513: val_loss did not improve from 0.83881
#
# Epoch 00514: val_loss did not improve from 0.83881
#
# Epoch 00515: val_loss did not improve from 0.83881
#
# Epoch 00516: val_loss did not improve from 0.83881
#
# Epoch 00517: val_loss did not improve from 0.83881
#
# Epoch 00518: val_loss did not improve from 0.83881
#
# Epoch 00519: val_loss did not improve from 0.83881
#
# Epoch 00520: val_loss did not improve from 0.83881
#
# Epoch 00521: val_loss did not improve from 0.83881
#
# Epoch 00522: val_loss improved from 0.83881 to 0.82728, saving model to models_best_nn.h5
#
# Epoch 00523: val_loss improved from 0.82728 to 0.73707, saving model to models_best_nn.h5
#
# Epoch 00524: val_loss did not improve from 0.73707
#
# Epoch 00525: val_loss did not improve from 0.73707
#
# Epoch 00526: val_loss did not improve from 0.73707
#
# Epoch 00527: val_loss did not improve from 0.73707
#
# Epoch 00528: val_loss did not improve from 0.73707
#
# Epoch 00529: val_loss did not improve from 0.73707
#
# Epoch 00530: val_loss did not improve from 0.73707
#
# Epoch 00531: val_loss did not improve from 0.73707
#
# Epoch 00532: val_loss did not improve from 0.73707
#
# Epoch 00533: val_loss did not improve from 0.73707
#
# Epoch 00534: val_loss did not improve from 0.73707
#
# Epoch 00535: val_loss did not improve from 0.73707
#
# Epoch 00536: val_loss did not improve from 0.73707
#
# Epoch 00537: val_loss did not improve from 0.73707
#
# Epoch 00538: val_loss did not improve from 0.73707
#
# Epoch 00539: val_loss did not improve from 0.73707
#
# Epoch 00540: val_loss did not improve from 0.73707
#
# Epoch 00541: val_loss did not improve from 0.73707
#
# Epoch 00542: val_loss did not improve from 0.73707
#
# Epoch 00543: val_loss did not improve from 0.73707
#
# Epoch 00544: val_loss did not improve from 0.73707
#
# Epoch 00545: val_loss did not improve from 0.73707
#
# Epoch 00546: val_loss did not improve from 0.73707
#
# Epoch 00547: val_loss did not improve from 0.73707
#
# Epoch 00548: val_loss did not improve from 0.73707
#
# Epoch 00549: val_loss did not improve from 0.73707
#
# Epoch 00550: val_loss did not improve from 0.73707
#
# Epoch 00551: val_loss did not improve from 0.73707
#
# Epoch 00552: val_loss improved from 0.73707 to 0.71071, saving model to models_best_nn.h5
#
# Epoch 00553: val_loss did not improve from 0.71071
#
# Epoch 00554: val_loss did not improve from 0.71071
#
# Epoch 00555: val_loss did not improve from 0.71071
#
# Epoch 00556: val_loss did not improve from 0.71071
#
# Epoch 00557: val_loss did not improve from 0.71071
#
# Epoch 00558: val_loss did not improve from 0.71071
#
# Epoch 00559: val_loss did not improve from 0.71071
#
# Epoch 00560: val_loss did not improve from 0.71071
#
# Epoch 00561: val_loss did not improve from 0.71071
#
# Epoch 00562: val_loss did not improve from 0.71071
#
# Epoch 00563: val_loss did not improve from 0.71071
#
# Epoch 00564: val_loss improved from 0.71071 to 0.70348, saving model to models_best_nn.h5
#
# Epoch 00565: val_loss did not improve from 0.70348
#
# Epoch 00566: val_loss did not improve from 0.70348
#
# Epoch 00567: val_loss did not improve from 0.70348
#
# Epoch 00568: val_loss did not improve from 0.70348
#
# Epoch 00569: val_loss did not improve from 0.70348
#
# Epoch 00570: val_loss did not improve from 0.70348
#
# Epoch 00571: val_loss did not improve from 0.70348
#
# Epoch 00572: val_loss did not improve from 0.70348
#
# Epoch 00573: val_loss did not improve from 0.70348
#
# Epoch 00574: val_loss did not improve from 0.70348
#
# Epoch 00575: val_loss did not improve from 0.70348
#
# Epoch 00576: val_loss did not improve from 0.70348
#
# Epoch 00577: val_loss did not improve from 0.70348
#
# Epoch 00578: val_loss did not improve from 0.70348
#
# Epoch 00579: val_loss did not improve from 0.70348
#
# Epoch 00580: val_loss did not improve from 0.70348
#
# Epoch 00581: val_loss did not improve from 0.70348
#
# Epoch 00582: val_loss did not improve from 0.70348
#
# Epoch 00583: val_loss did not improve from 0.70348
#
# Epoch 00584: val_loss did not improve from 0.70348
#
# Epoch 00585: val_loss did not improve from 0.70348
#
# Epoch 00586: val_loss did not improve from 0.70348
# Epoch 00587: val_loss did not improve from 0.70348
#
# Epoch 00588: val_loss did not improve from 0.70348
#
# Epoch 00589: val_loss did not improve from 0.70348
#
# Epoch 00590: val_loss did not improve from 0.70348
#
# Epoch 00591: val_loss did not improve from 0.70348
#
# Epoch 00592: val_loss did not improve from 0.70348
#
# Epoch 00593: val_loss did not improve from 0.70348
#
# Epoch 00594: val_loss did not improve from 0.70348
#
# Epoch 00595: val_loss did not improve from 0.70348
#
# Epoch 00596: val_loss did not improve from 0.70348
#
# Epoch 00597: val_loss did not improve from 0.70348
#
# Epoch 00598: val_loss did not improve from 0.70348
#
# Epoch 00599: val_loss did not improve from 0.70348
#
# Epoch 00600: val_loss did not improve from 0.70348
#
# Epoch 00601: val_loss did not improve from 0.70348
#
# Epoch 00602: val_loss did not improve from 0.70348
#
# Epoch 00603: val_loss did not improve from 0.70348
#
# Epoch 00604: val_loss did not improve from 0.70348
#
# Epoch 00605: val_loss did not improve from 0.70348
#
# Epoch 00606: val_loss did not improve from 0.70348
#
# Epoch 00607: val_loss did not improve from 0.70348
#
# Epoch 00608: val_loss improved from 0.70348 to 0.69957, saving model to models_best_nn.h5
#
# Epoch 00609: val_loss did not improve from 0.69957
#
# Epoch 00610: val_loss did not improve from 0.69957
#
# Epoch 00611: val_loss did not improve from 0.69957
#
# Epoch 00612: val_loss did not improve from 0.69957
#
# Epoch 00613: val_loss did not improve from 0.69957
#
# Epoch 00614: val_loss did not improve from 0.69957
#
# Epoch 00615: val_loss did not improve from 0.69957
#
# Epoch 00616: val_loss did not improve from 0.69957
#
# Epoch 00617: val_loss did not improve from 0.69957
#
# Epoch 00618: val_loss did not improve from 0.69957
#
# Epoch 00619: val_loss did not improve from 0.69957
#
# Epoch 00620: val_loss did not improve from 0.69957
#
# Epoch 00621: val_loss did not improve from 0.69957
#
# Epoch 00622: val_loss did not improve from 0.69957
#
# Epoch 00623: val_loss did not improve from 0.69957
#
# Epoch 00624: val_loss did not improve from 0.69957
#
# Epoch 00625: val_loss improved from 0.69957 to 0.62853, saving model to models_best_nn.h5
#
# Epoch 00626: val_loss did not improve from 0.62853
#
# Epoch 00627: val_loss did not improve from 0.62853
#
# Epoch 00628: val_loss did not improve from 0.62853
#
# Epoch 00629: val_loss did not improve from 0.62853
#
# Epoch 00630: val_loss did not improve from 0.62853
#
# Epoch 00631: val_loss did not improve from 0.62853
#
# Epoch 00632: val_loss did not improve from 0.62853
#
# Epoch 00633: val_loss did not improve from 0.62853
#
# Epoch 00634: val_loss did not improve from 0.62853
#
# Epoch 00635: val_loss did not improve from 0.62853
#
# Epoch 00636: val_loss did not improve from 0.62853
#
# Epoch 00637: val_loss did not improve from 0.62853
#
# Epoch 00638: val_loss did not improve from 0.62853
#
# Epoch 00639: val_loss did not improve from 0.62853
#
# Epoch 00640: val_loss did not improve from 0.62853
#
# Epoch 00641: val_loss did not improve from 0.62853
#
# Epoch 00642: val_loss did not improve from 0.62853
#
# Epoch 00643: val_loss did not improve from 0.62853
#
# Epoch 00644: val_loss did not improve from 0.62853
#
# Epoch 00645: val_loss did not improve from 0.62853
#
# Epoch 00646: val_loss did not improve from 0.62853
#
# Epoch 00647: val_loss did not improve from 0.62853
#
# Epoch 00648: val_loss improved from 0.62853 to 0.60982, saving model to models_best_nn.h5
#
# Epoch 00649: val_loss did not improve from 0.60982
#
# Epoch 00650: val_loss did not improve from 0.60982
#
# Epoch 00651: val_loss did not improve from 0.60982
#
# Epoch 00652: val_loss did not improve from 0.60982
#
# Epoch 00653: val_loss did not improve from 0.60982
#
# Epoch 00654: val_loss did not improve from 0.60982
#
# Epoch 00655: val_loss did not improve from 0.60982
#
# Epoch 00656: val_loss did not improve from 0.60982
#
# Epoch 00657: val_loss did not improve from 0.60982
#
# Epoch 00658: val_loss improved from 0.60982 to 0.56966, saving model to models_best_nn.h5
#
# Epoch 00659: val_loss did not improve from 0.56966
#
# Epoch 00660: val_loss did not improve from 0.56966
#
# Epoch 00661: val_loss did not improve from 0.56966
#
# Epoch 00662: val_loss did not improve from 0.56966
#
# Epoch 00663: val_loss did not improve from 0.56966
#
# Epoch 00664: val_loss did not improve from 0.56966
#
# Epoch 00665: val_loss did not improve from 0.56966
#
# Epoch 00666: val_loss did not improve from 0.56966
#
# Epoch 00667: val_loss did not improve from 0.56966
#
# Epoch 00668: val_loss did not improve from 0.56966
#
# Epoch 00669: val_loss did not improve from 0.56966
#
# Epoch 00670: val_loss did not improve from 0.56966
#
# Epoch 00671: val_loss did not improve from 0.56966
#
# Epoch 00672: val_loss did not improve from 0.56966
#
# Epoch 00673: val_loss did not improve from 0.56966
#
# Epoch 00674: val_loss did not improve from 0.56966
#
# Epoch 00675: val_loss did not improve from 0.56966
#
# Epoch 00676: val_loss did not improve from 0.56966
#
# Epoch 00677: val_loss did not improve from 0.56966
#
# Epoch 00678: val_loss did not improve from 0.56966
#
# Epoch 00679: val_loss did not improve from 0.56966
#
# Epoch 00680: val_loss did not improve from 0.56966
#
# Epoch 00681: val_loss did not improve from 0.56966
#
# Epoch 00682: val_loss did not improve from 0.56966
#
# Epoch 00683: val_loss did not improve from 0.56966
#
# Epoch 00684: val_loss did not improve from 0.56966
#
# Epoch 00685: val_loss did not improve from 0.56966
#
# Epoch 00686: val_loss did not improve from 0.56966
#
# Epoch 00687: val_loss did not improve from 0.56966
#
# Epoch 00688: val_loss did not improve from 0.56966
#
# Epoch 00689: val_loss did not improve from 0.56966
#
# Epoch 00690: val_loss did not improve from 0.56966
#
# Epoch 00691: val_loss did not improve from 0.56966
#
# Epoch 00692: val_loss did not improve from 0.56966
#
# Epoch 00693: val_loss did not improve from 0.56966
#
# Epoch 00694: val_loss did not improve from 0.56966
#
# Epoch 00695: val_loss did not improve from 0.56966
#
# Epoch 00696: val_loss did not improve from 0.56966
#
# Epoch 00697: val_loss did not improve from 0.56966
#
# Epoch 00698: val_loss did not improve from 0.56966
#
# Epoch 00699: val_loss did not improve from 0.56966
#
# Epoch 00700: val_loss did not improve from 0.56966
#
# Epoch 00701: val_loss did not improve from 0.56966
#
# Epoch 00702: val_loss did not improve from 0.56966
#
# Epoch 00703: val_loss did not improve from 0.56966
#
# Epoch 00704: val_loss did not improve from 0.56966
#
# Epoch 00705: val_loss did not improve from 0.56966
#
# Epoch 00706: val_loss did not improve from 0.56966
#
# Epoch 00707: val_loss did not improve from 0.56966
#
# Epoch 00708: val_loss did not improve from 0.56966

# %%
# view the history of model loss & validation loss:

history = pd.DataFrame(mod.history.history).plot()
history

plt.ylim(0, 20)
# Out:
# (0.0, 20.0)

# %%
# recall the best model:
mod = tf.keras.models.load_model('models_best_nn.h5')


# create and view predictions versus actual for test data:

predictions = mod.predict(X_test).reshape(y_test.shape)
pd.DataFrame({'predictions': predictions, 'actual': y_test}).plot.scatter(x='predictions', y='actual', figsize=(15,8))
plt.xlim(0,)
plt.ylim(0,)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# (0.0, 145.78884999999997)

# %%
# add a model prediction column to the original dataframe
# (note the model does not treat the data as a time series):

ts = df.copy()
ts['f30d_pred'] = mod.predict(scal.transform(df[X.columns].values))
ts
# Out:
#             price  t90d_mean  t30d_mean  f30d_mean  US Production  storage  \
# 1990-01-01  21.84  20.387000  21.151000  22.904667           7565   904134
# 1990-01-02  22.88  20.417111  21.238333  22.933000           7565   904134
# 1990-01-03  23.81  20.460000  21.357333  22.927333           7565   904134
# 1990-01-04  23.41  20.499111  21.463667  22.901667           7565   904134
# 1990-01-05  23.07  20.534444  21.550667  22.889333           7512   904076
# ...           ...        ...        ...        ...            ...      ...
# 2021-10-14  81.43  71.349222  75.840333  82.745000          11400  1043945
# 2021-10-15  82.39  71.467333  76.167000  82.726333          11300  1041820
# 2021-10-16  82.39  71.585444  76.490333  82.675667          11300  1041820
# 2021-10-17  82.39  71.762556  76.833667  82.624333          11300  1041820
# 2021-10-18  82.62  71.932556  77.184667  82.570000          11300  1041820
#
#                      gdp  f30d_mean_gdp  f365d_mean_gdp  f30d_pred
# 1990-01-01   9340.478778    9352.766670     9368.661736  22.017687
# 1990-01-02   9341.326219    9353.614111     9368.475865  22.795509
# 1990-01-03   9342.173660    9354.461552     9368.287526  23.292566
# 1990-01-04   9343.021100    9355.303125     9368.096719  23.127172
# 1990-01-05   9343.868541    9356.138830     9367.903444  22.723604
# ...                  ...            ...             ...        ...
# 2021-10-14  19617.739033   19653.189860    20048.135191  83.057686
# 2021-10-15  19620.178531   19655.643559    20050.372550  84.281700
# 2021-10-16  19622.618029   19658.098442    20052.607767  84.234459
# 2021-10-17  19625.057527   19660.554507    20054.840844  84.162079
# 2021-10-18  19627.497025   19663.011756    20057.071779  84.227608
#
# [11613 rows x 10 columns]

# %%
# general visualization of overall model fit
# includes train + test data:

ts[['f30d_pred', 'f30d_mean']].plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
# overall model fit, most recent data:

ts[-3000:][['f30d_pred', 'f30d_mean']].plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
# overall model fit with overlaid visualization of current spot rate:

ts[-1200:][['price', 'f30d_pred', 'f30d_mean']].plot()

plt.ylim(0,)
# Out:
# (0.0, 88.0502851409912)

# %% [markdown]
# <h1><u>Comparison to Baseline</u></h1>

# %% [markdown]
# ### It's common to base economic analysis on the presumption, for lack of better information, that ongoing oil prices remain flat. The model at issue should at least improve upon this as a baseline.
#
# #### I'm considering two alternative baselines which may add to or replace the current (daily spot rate) baseline:
# - 30-days average spot price (similar to daily but more stable)
# - Trailing 12-months average spot price (basis for SEC booked reserves economics)

# %%
# a visualization of current spot rate (x-axis) versus forward-30-day mean (y-axis):

ts.plot.scatter(x='price', y='f30d_mean')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='price', ylabel='f30d_mean'>

# %%
# quick view of model results
# mse & mae based on test data & predictions:

model_mse, model_mae = mse(y_test, predictions), mae(y_test, predictions)
model_mse, model_mae
# Out:
# (0.5696606243379909, 0.5201947444064654)

# %%
# comparison view of "assumed flat oil price"
# mse & mae based on test data vs. same-date spot price

X_test_price = pd.DataFrame(scal.inverse_transform(X_test))[0]

base_mse, base_mae = mse(y_test, X_test_price), mae(y_test, X_test_price)
base_mse, base_mae
# Out:
# (9.283846522483735, 2.0102813815537695)

# %%
# visualize comparison of model vs. baseline error: 

xs = ['Base MSE', 'Model MSE', 'Base MAE', 'Model MAE']
ys = [base_mse, model_mse, base_mae, model_mae]

plt.bar(xs, ys, color=['r', 'b', 'r', 'b']);

for i in range(len(xs)):
    plt.text(xs[i], ys[i] + 0.1, '{:.2f}'.format(ys[i]))

# %% [markdown]
# # Error Trends
#
# #### Insofar as the most critical decisions based on oil price would be made in anticipation of large changes in the oil price, it's desirable to know how model error varies relative to the rapidity of change in the spot rate. I'll check this by plotting the 'price deviation' (forward-30-days average price - spot rate) versus model prediction error.
#
# #### Observed trending in the model error could also be used to infer missing determinants that should be accounted for or added to the model.

# %%
# construct a dataframe with actual spot price, prediction, and actual forward-30-days mean price: 

test_df = pd.DataFrame(scal.inverse_transform(X_test), columns=X.columns)[['price']]
test_df['prediction'] = predictions
test_df['actual'] = y_test.values

# measure the relevant errors:

test_df['pred_error'] = test_df['prediction'] - test_df['actual']
test_df['price_dev'] = test_df['actual'] - test_df['price']

test_df
# Out:
#       price  prediction     actual  pred_error  price_dev
# 0     72.73   71.632790  71.212333    0.420456  -1.517667
# 1     58.08   62.474953  63.413000   -0.938047   5.333000
# 2     99.40   98.376183  98.813000   -0.436817  -0.587000
# 3     24.79   27.231758  27.979667   -0.747909   3.189667
# 4     18.70   18.151871  18.701667   -0.549796   0.001667
# ...     ...         ...        ...         ...        ...
# 3479  48.34   50.083183  49.547667    0.535517   1.207667
# 3480  44.08   49.151833  50.134333   -0.982501   6.054333
# 3481  48.41   50.525974  51.819667   -1.293692   3.409667
# 3482  51.46   49.261925  50.064333   -0.802409  -1.395667
# 3483  20.57   25.509676  27.135667   -1.625991   6.565667
#
# [3484 rows x 5 columns]

# %%
plt.scatter(test_df['price_dev'], test_df['pred_error'], 
            linewidth=0.25, 
            edgecolors='white',
            s=50,
            c=abs(test_df['pred_error']))

plt.xlabel('Price Deviation (Forward-30-Days Mean - Spot Price)')
plt.ylabel('Prediction Error (Actual Forward-30-Days Mean - Predicted)');

# %%
plt.hist2d(test_df['price_dev'], test_df['pred_error'], bins=100)
plt.xlabel('Price Deviation (Forward-30-Days Mean - Spot Price)')
plt.ylabel('Prediction Error (Actual Forward-30-Days Mean - Predicted)');
